# %%
import pandas as pd
# Out:
# C:\Users\mdbab\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_excel("C:/Users//mdbab//OneDrive//Desktop//DATA SCIENCE MATERIAL//DATA//global_superstore//Global Superstore.xls")

# %%
data.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# 1   FUR-CH-10003950   Furniture       Chairs
# 2   TEC-PH-10004664  Technology       Phones
# 3   TEC-PH-10004583  Technology       Phones
# 4  TEC-SHA-10000501  Technology      Copiers
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
data.shape
# Out:
# (51290, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(2), object(15)
# memory usage: 9.4+ MB

# %% [raw]
# Droping of Row ID and Postal Code

# %%
Data= data.drop(columns=["Row ID","Postal Code"],axis=1)

# %% [markdown]
# **Checking of duplicated data**

# %%
Data.duplicated().value_counts()   # No dulpicated data
# Out:
# False    51290
# Name: count, dtype: int64

# %% [markdown]
# **Checking for Null values**

# %%
Data.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
Data.isnull().sum()/len(Data)*100
# Out:
# Order ID          0.0
# Order Date        0.0
# Ship Date         0.0
# Ship Mode         0.0
# Customer ID       0.0
# Customer Name     0.0
# Segment           0.0
# City              0.0
# State             0.0
# Country           0.0
# Market            0.0
# Region            0.0
# Product ID        0.0
# Category          0.0
# Sub-Category      0.0
# Product Name      0.0
# Sales             0.0
# Quantity          0.0
# Discount          0.0
# Profit            0.0
# Shipping Cost     0.0
# Order Priority    0.0
# dtype: float64

# %%
Data.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                          51290                          51290
# mean   2013-05-11 21:26:49.155781120  2013-05-15 20:42:42.745174528
# min              2011-01-01 00:00:00            2011-01-03 00:00:00
# 25%              2012-06-19 00:00:00            2012-06-23 00:00:00
# 50%              2013-07-08 00:00:00            2013-07-12 00:00:00
# 75%              2014-05-22 00:00:00            2014-05-26 00:00:00
# max              2014-12-31 00:00:00            2015-01-07 00:00:00
# std                              NaN                            NaN
#
#               Sales      Quantity      Discount        Profit  Shipping Cost
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.610982      26.375818
# min        0.444000      1.000000      0.000000  -6599.978000       0.002000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000
# std      487.565361      2.278766      0.212280    174.340972      57.296810

# %% [markdown]
# **Checking of Outliers**

# %%
import seaborn as sns

# %%
sns.boxplot(Data)
# Out:
# <Axes: >

# %%
Data.shape
# Out:
# (51290, 22)

# %%
#Dealing outliers for Sales feature by IQR method
Q1=30.758625
Q3=251.053200
IQR= Q3-Q1
min_sales= Q1-1.5*IQR
max_sales= Q3+1.5*IQR
print("Minimum range is ",min_sales)
print("maximum range is ",max_sales)
data1 = Data[(Data["Sales"] > min_sales) & (Data["Sales"] < max_sales)]
print("Shape of data :", data1.shape)
# Out:
# Minimum range is  -299.6832375
# maximum range is  581.4950625
# Shape of data : (45635, 22)

# %%
#Dealing outliers for Quantity feature by IQR method
Q1=2.000000
Q3=5.000000
IQR= Q3-Q1
min_quntity= Q1-1.5*IQR
max_quntity= Q3+1.5*IQR
print("Minimum range is ",min_quntity)
print("maximum range is ",max_quntity)
data2 = data1[(data1["Quantity"] > min_quntity) & (data1["Quantity"] < max_quntity)]
print("Shape of data :", data2.shape)
# Out:
# Minimum range is  -2.5
# maximum range is  9.5
# Shape of data : (45027, 22)

# %%
#Dealing outliers for Discount feature by IQR method
Q1=0.000000
Q3=0.200000
IQR= Q3-Q1
min_dis= Q1-1.5*IQR
max_dis= Q3+1.5*IQR
print("Minimum range is ",min_dis)
print("maximum range is ",max_dis)
data3 = data2[(data2["Discount"] > min_dis) & (data2["Discount"] < max_dis)]
print("Shape of data :", data3.shape)
# Out:
# Minimum range is  -0.30000000000000004
# maximum range is  0.5
# Shape of data : (39542, 22)

# %%
#Dealing outliers for Profit feature by IQR method
Q1=0.000000
Q3=36.810000
IQR= Q3-Q1
min_profit= Q1-1.5*IQR
max_profit= Q3+1.5*IQR
print("Minimum range is ",min_profit)
print("maximum range is ",max_profit)
data4= data3[(data3["Profit"] > min_profit) & (data3["Profit"] < max_profit)]
print("Shape of data :", data4.shape)
# Out:
# Minimum range is  -55.215
# maximum range is  92.025
# Shape of data : (36057, 22)

# %%
#Dealing outliers for Shipping Cost feature by IQR method
Q1=2.610000
Q3=24.450000
IQR= Q3-Q1
min_cost= Q1-1.5*IQR
max_cost= Q3+1.5*IQR
print("Minimum range is ",min_cost)
print("maximum range is ",max_cost)
data5= data4[(data4["Shipping Cost"] > min_cost) & (data4["Shipping Cost"] < max_cost)]
print("Shape of data :", data5.shape)
# Out:
# Minimum range is  -30.15
# maximum range is  57.209999999999994
# Shape of data : (35249, 22)

# %%
sns.boxplot(data5)
# Out:
# <Axes: >

# %%
print("Shape of Data before rempoval of outliers: ",data.shape)
print("Shape of Data after rempoval of outliers: ",data5.shape)
# Out:
# Shape of Data before rempoval of outliers:  (51290, 24)
# Shape of Data after rempoval of outliers:  (35249, 22)

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35249 entries, 5909 to 51289
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        35249 non-null  object
#  1   Order Date      35249 non-null  datetime64[ns]
#  2   Ship Date       35249 non-null  datetime64[ns]
#  3   Ship Mode       35249 non-null  object
#  4   Customer ID     35249 non-null  object
#  5   Customer Name   35249 non-null  object
#  6   Segment         35249 non-null  object
#  7   City            35249 non-null  object
#  8   State           35249 non-null  object
#  9   Country         35249 non-null  object
#  10  Market          35249 non-null  object
#  11  Region          35249 non-null  object
#  12  Product ID      35249 non-null  object
#  13  Category        35249 non-null  object
#  14  Sub-Category    35249 non-null  object
#  15  Product Name    35249 non-null  object
#  16  Sales           35249 non-null  float64
#  17  Quantity        35249 non-null  int64
#  18  Discount        35249 non-null  float64
#  19  Profit          35249 non-null  float64
#  20  Shipping Cost   35249 non-null  float64
#  21  Order Priority  35249 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(1), object(15)
# memory usage: 6.2+ MB

# %%
data5.head()
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 5909  CA-2013-161816 2013-04-29 2013-05-02     First Class    NB-18655
# 5914   ID-2013-79432 2013-12-11 2013-12-14    Second Class    JK-15325
# 5915  CA-2014-120376 2014-12-23 2014-12-26     First Class    TP-21130
# 5921   IN-2014-22606 2014-08-11 2014-08-11        Same Day    RC-19960
# 5922   ID-2014-85529 2014-05-08 2014-05-12  Standard Class    AG-10300
#
#             Customer Name    Segment      City            State  \
# 5909            Nona Balk  Corporate    Dallas            Texas
# 5914    Jason Klamczynski  Corporate  Adelaide  South Australia
# 5915     Theone Pippenger   Consumer   Detroit         Michigan
# 5921           Ryan Crowe   Consumer   Wenzhou         Zhejiang
# 5922  Aleksandra Gannaway  Corporate  Auckland         Auckland
#
#             Country  ...       Product ID    Category Sub-Category  \
# 5909  United States  ...  TEC-PH-10003012  Technology       Phones
# 5914      Australia  ...  FUR-FU-10001477   Furniture  Furnishings
# 5915  United States  ...  FUR-TA-10004534   Furniture       Tables
# 5921          China  ...  TEC-AC-10000861  Technology  Accessories
# 5922    New Zealand  ...  FUR-BO-10001872   Furniture    Bookcases
#
#                                           Product Name    Sales Quantity  \
# 5909  Nortel Meridian M3904 Professional Digital phone  369.576        3
# 5914                   Rubbermaid Stacking Tray, Black  158.760        7
# 5915                   Bevis 44 x 96 Conference Tables  411.800        2
# 5921                         SanDisk Router, Erganomic  254.160        1
# 5922                     Bush Stackable Bookrack, Pine  449.496        6
#
#       Discount   Profit  Shipping Cost  Order Priority
# 5909       0.2  41.5773          57.20          Medium
# 5914       0.1  21.0000          57.12        Critical
# 5915       0.0  70.0060          57.12            High
# 5921       0.0  40.6500          57.07          Medium
# 5922       0.4 -30.0240          57.05            High
#
# [5 rows x 22 columns]

# %%
data5.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                          35249                          35249
# mean   2013-05-14 05:38:03.128599552  2013-05-18 05:49:09.836875008
# min              2011-01-01 00:00:00            2011-01-03 00:00:00
# 25%              2012-06-23 00:00:00            2012-06-27 00:00:00
# 50%              2013-07-12 00:00:00            2013-07-16 00:00:00
# 75%              2014-05-23 00:00:00            2014-05-27 00:00:00
# max              2014-12-31 00:00:00            2015-01-07 00:00:00
# std                              NaN                            NaN
#
#               Sales      Quantity      Discount        Profit  Shipping Cost
# count  35249.000000  35249.000000  35249.000000  35249.000000   35249.000000
# mean      97.742393      3.100740      0.079318     15.284637       9.658355
# min        0.990000      1.000000      0.000000    -55.092000       0.002000
# 25%       27.240000      2.000000      0.000000      2.520000       2.250000
# 50%       59.700000      3.000000      0.000000      9.294000       5.570000
# 75%      132.870000      4.000000      0.150000     24.476800      12.874000
# max      581.250000      9.000000      0.470000     91.995400      57.200000
# std      101.021225      1.877635      0.132456     23.149736      10.778477

# %% [markdown]
# **Encoding of Catogorical columns**

# %%
# !pip install feature_engine -q
from feature_engine.encoding import MeanEncoder

# %%
data6 = data5.copy()

# %%
col=['Order ID','Ship Mode','Customer ID','Customer Name','Segment','City','State','Country','Market','Region','Product ID','Category','Sub-Category','Product Name','Order Priority']

# %%
encoder=MeanEncoder(variables=col)

# %%
data6[col]=encoder.fit_transform(data5[col],data5['Profit'])

# %%
data6.head()
# Out:
#        Order ID Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  \
# 5909  23.636450 2013-04-29 2013-05-02  14.471676     8.509783       8.869566
# 5914  37.235250 2013-12-11 2013-12-14  15.235830    19.239438      19.229245
# 5915  54.862133 2014-12-23 2014-12-26  14.471676    12.718453      13.038158
# 5921  40.650000 2014-08-11 2014-08-11  14.001846    16.472477      16.348334
# 5922 -15.603000 2014-05-08 2014-05-12  15.593019    18.731624      18.965731
#
#         Segment       City      State    Country  ...  Product ID   Category  \
# 5909  15.308780   7.708622   6.087340  14.608235  ...   68.855529  23.482184
# 5914  15.308780  15.435057  16.840451  11.917414  ...   26.816182  18.251340
# 5915  15.276795  27.047018  24.457016  14.608235  ...   70.006000  18.251340
# 5921  15.276795  32.460000  21.641695  23.771690  ...   60.975000  23.482184
# 5922  15.308780  -9.152727  -9.888836   9.335688  ...  -30.024000  18.251340
#
#       Sub-Category  Product Name    Sales  Quantity  Discount   Profit  \
# 5909     23.632206     68.855529  369.576         3       0.2  41.5773
# 5914     15.480692     17.982545  158.760         7       0.1  21.0000
# 5915      7.744819     70.006000  411.800         2       0.0  70.0060
# 5921     20.301385     60.975000  254.160         1       0.0  40.6500
# 5922     25.623179     23.259111  449.496         6       0.4 -30.0240
#
#       Shipping Cost  Order Priority
# 5909          57.20       15.549436
# 5914          57.12       13.228476
# 5915          57.12       15.272388
# 5921          57.07       15.549436
# 5922          57.05       15.272388
#
# [5 rows x 22 columns]

# %% [markdown]
# # Encoding Datetime Quaterly

# %%
data6["Ordered_Quaterly"]=data6['Order Date'].dt.quarter
data6["Shiped_Quaterly"]=data6['Ship Date'].dt.quarter

# %%
data6.head()
# Out:
#        Order ID Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  \
# 5909  23.636450 2013-04-29 2013-05-02  14.471676     8.509783       8.869566
# 5914  37.235250 2013-12-11 2013-12-14  15.235830    19.239438      19.229245
# 5915  54.862133 2014-12-23 2014-12-26  14.471676    12.718453      13.038158
# 5921  40.650000 2014-08-11 2014-08-11  14.001846    16.472477      16.348334
# 5922 -15.603000 2014-05-08 2014-05-12  15.593019    18.731624      18.965731
#
#         Segment       City      State    Country  ...  Sub-Category  \
# 5909  15.308780   7.708622   6.087340  14.608235  ...     23.632206
# 5914  15.308780  15.435057  16.840451  11.917414  ...     15.480692
# 5915  15.276795  27.047018  24.457016  14.608235  ...      7.744819
# 5921  15.276795  32.460000  21.641695  23.771690  ...     20.301385
# 5922  15.308780  -9.152727  -9.888836   9.335688  ...     25.623179
#
#       Product Name    Sales  Quantity  Discount   Profit  Shipping Cost  \
# 5909     68.855529  369.576         3       0.2  41.5773          57.20
# 5914     17.982545  158.760         7       0.1  21.0000          57.12
# 5915     70.006000  411.800         2       0.0  70.0060          57.12
# 5921     60.975000  254.160         1       0.0  40.6500          57.07
# 5922     23.259111  449.496         6       0.4 -30.0240          57.05
#
#       Order Priority  Ordered_Quaterly  Shiped_Quaterly
# 5909       15.549436                 2                2
# 5914       13.228476                 4                4
# 5915       15.272388                 4                4
# 5921       15.549436                 3                3
# 5922       15.272388                 2                2
#
# [5 rows x 24 columns]

# %%
data6=data6.drop(columns=['Order Date','Ship Date'])

# %%
data6.head()
# Out:
#        Order ID  Ship Mode  Customer ID  Customer Name    Segment       City  \
# 5909  23.636450  14.471676     8.509783       8.869566  15.308780   7.708622
# 5914  37.235250  15.235830    19.239438      19.229245  15.308780  15.435057
# 5915  54.862133  14.471676    12.718453      13.038158  15.276795  27.047018
# 5921  40.650000  14.001846    16.472477      16.348334  15.276795  32.460000
# 5922 -15.603000  15.593019    18.731624      18.965731  15.308780  -9.152727
#
#           State    Country     Market     Region  ...  Sub-Category  \
# 5909   6.087340  14.608235  14.608235  15.858607  ...     23.632206
# 5914  16.840451  11.917414  12.951101  11.511377  ...     15.480692
# 5915  24.457016  14.608235  14.608235  15.858607  ...      7.744819
# 5921  21.641695  23.771690  12.951101  23.484788  ...     20.301385
# 5922  -9.888836   9.335688  12.951101  11.511377  ...     25.623179
#
#       Product Name    Sales  Quantity  Discount   Profit  Shipping Cost  \
# 5909     68.855529  369.576         3       0.2  41.5773          57.20
# 5914     17.982545  158.760         7       0.1  21.0000          57.12
# 5915     70.006000  411.800         2       0.0  70.0060          57.12
# 5921     60.975000  254.160         1       0.0  40.6500          57.07
# 5922     23.259111  449.496         6       0.4 -30.0240          57.05
#
#       Order Priority  Ordered_Quaterly  Shiped_Quaterly
# 5909       15.549436                 2                2
# 5914       13.228476                 4                4
# 5915       15.272388                 4                4
# 5921       15.549436                 3                3
# 5922       15.272388                 2                2
#
# [5 rows x 22 columns]

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data9=scaler.fit_transform(data6)
data9=pd.DataFrame(data9)

# %%
data9.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.455985 -1.681310 -1.305424 -1.639357  1.486866 -0.707533 -0.992835
# 1  1.198441 -0.100940  0.762037  1.008036  1.486866  0.014048  0.167948
# 2  2.160818 -1.681310 -0.494470 -0.574083 -0.482942  1.098503  0.990145
# 3  1.384876 -2.652979  0.228881  0.271825 -0.482942  1.604028  0.686235
# 4 -1.686377  0.637774  0.664188  0.940696  1.486866 -2.282236 -2.717440
#
#          7         8         9   ...        12        13        14        15  \
# 0 -0.085345 -0.231421  0.127468  ...  1.522181  3.922175  2.690895 -0.053654
# 1 -0.424861 -0.798385 -0.837970  ...  0.035751  0.197526  0.604016  2.076716
# 2 -0.085345 -0.231421  0.127468  ... -1.374888  4.006407  3.108872 -0.586246
# 3  1.070857 -0.798385  1.821098  ...  0.914805  3.345205  1.548386 -1.118839
# 4 -0.750611 -0.798385 -0.837970  ...  1.885235  0.583849  3.482027  1.544124
#
#          16        17        18        19        20        21
# 0  0.911121  1.135781  4.410857  0.456690 -0.747141 -0.730408
# 1  0.156142  0.246890  4.403435 -3.546203  1.130915  1.132420
# 2 -0.598837  2.363834  4.403435 -0.021126  1.130915  1.132420
# 3 -0.598837  1.095724  4.398796  0.456690  0.191887  0.201006
# 4  2.421079 -1.957227  4.396940 -0.021126 -0.747141 -0.730408
#
# [5 rows x 22 columns]

# %% [markdown]
# # Buliding of ML Model

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
x=data9.drop(columns=[18])
y=data9[18]

# %%
Xtrain,xtest,Ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state= 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
print("Intercept:",regressor.intercept_)
print("Coefficients",regressor.coef_)
# Out:
# Intercept: 0.00015064899844102406
# Coefficients [-3.94610882e-05 -1.42744905e-01  7.52041019e-03 -2.40410557e-03
#  -2.74592798e-03  9.84946401e-03 -4.89661826e-03  6.55988183e-03
#   7.57626021e-03 -6.49403076e-03 -2.05942310e-03  1.72885835e-02
#   2.98027550e-02  3.23195941e-02  7.37087039e-01  3.84239672e-02
#   4.98475422e-04  2.48232158e-02 -2.22361649e-01 -7.81251221e-03
#   7.58960716e-03]

# %%
y_pred = regressor.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error

# %%
accuracy_mse=mse(ytest,y_pred)

# %%
accuracy_mse
# Out:
# 0.30833481444849486

# %%
regressor.score(Xtrain,Ytrain)
# Out:
# 0.6881334641153906

# %%
from sklearn.metrics import r2_score

# %%
a=r2_score

# %%
accuracy_r2 = a(ytest,y_pred)

# %%
accuracy_r2
# Out:
# 0.6957541280773196

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV


parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20]}
lasso = Lasso()

grid_search = GridSearchCV(estimator=lasso, param_grid=parameters, scoring='r2', cv=5)
grid_search.fit(Xtrain, Ytrain)

print("Best parameters found: ", grid_search.best_params_)
print("Best R2 score found: ", grid_search.best_score_)
# Out:
# C:\Users\mdbab\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.037e+01, tolerance: 2.085e+00
#   model = cd_fast.enet_coordinate_descent(
# Best parameters found:  {'alpha': 0.001}
# Best R2 score found:  0.6870389352071726

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20]}
ridge = Ridge()

grid_search = GridSearchCV(estimator=ridge, param_grid=parameters, scoring='r2', cv=5)
grid_search.fit(Xtrain, Ytrain)

print("Best parameters found: ", grid_search.best_params_)
print("Best R2 score found: ", grid_search.best_score_)
print("Regression score : ", regressor.score)
# Out:
# Best parameters found:  {'alpha': 20}
# Best R2 score found:  0.6868390835815603
# Regression score :  <bound method RegressorMixin.score of LinearRegression()>

# %%
regressor.score(xtest,ytest)
# Out:
# 0.6957541280773196

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# %%
D_regressor = DecisionTreeRegressor(max_depth=8,min_samples_leaf=5)
D_regressor.fit(Xtrain,Ytrain)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=5)

# %%
y_pred = D_regressor.predict(xtest)

# %%
from sklearn.metrics import root_mean_squared_error
accuracy = r2_score(ytest, y_pred)

# %%
accuracy
# Out:
# 0.7602392506017412

# %%
D_regressor.score(Xtrain,Ytrain)
# Out:
# 0.8146355240311778

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
D_regressor_Aboost = AdaBoostRegressor(D_regressor)

# %%
D_regressor_Aboost.fit(x,y)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=8,
#                                                   min_samples_leaf=5))

# %%
y1=D_regressor_Aboost.predict(xtest)

# %%
accuracy_Aboost = r2_score(ytest,y1)

# %%
sss=D_regressor_Aboost.score(Xtrain,Ytrain)
print(sss)
# Out:
# 0.8456207174022675

# %%
accuracy_Aboost
# Out:
# 0.8466015259010565

# %% [markdown]
# # gradinent boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
D_regressor_Gboost = GradientBoostingRegressor()

# %%
D_regressor_Gboost.fit(x,y)
# Out:
# GradientBoostingRegressor()

# %%
y2=D_regressor_Gboost.predict(xtest)

# %%
accuracy_Gboost = r2_score(ytest,y2)

# %%
sa=D_regressor_Gboost.score(Xtrain,Ytrain)
print(sa)
# Out:
# 0.7965615824293169

# %%
accuracy_Gboost
# Out:
# 0.7984883528196403

# %% [markdown]
# # Random Forest with GridSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
rr= RandomForestRegressor()

# %%
X=data9.drop(columns=[18])
Y=data9[18]

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,xtest,Ytrain,ytest=train_test_split(X,Y,test_size=0.3,random_state= 1)

# %%
rr.fit(Xtrain,Ytrain)
# Out:
# RandomForestRegressor()

# %%
y3=rr.predict(xtest)
y4=rr.predict(Xtrain)

# %%
accuracy_train=r2_score(Ytrain,y4)
accuracy_test= r2_score(ytest,y3)

# %%
print("accuracy_train: ",accuracy_train)
print("accuracy_test: ",accuracy_test)
# Out:
# accuracy_train:  0.9678543502937867
# accuracy_test:  0.7776748763124994

# %%
para={'n_estimators':[100,200,300,400],'max_depth':[3,4,5,7,9]}

# %%
grid=GridSearchCV(estimator=rr,param_grid=para)

# %%
grid.fit(Xtrain,Ytrain)

# %%
grid.best_params_

# %%
y5=grid.predict(xtest)

# %%
accuracy_grid=r2_score(ytest,y5)
accuracy_grid

# %%
grid1=GridSearchCV

# %%
rf=RandomForestRegressor(n_estimators=150,max_depth=7)

# %%
rf.fit(Xtrain,Ytrain)

# %%
y6=rf.predict(xtest)

# %%
accuracy_ranF=r2_score(ytest,y6)
accuracy_ranF

# %%
grid_rf=GridSearchCV(estimator=rf,param_grid=para)

# %%
grid_rf.fit(Xtrain,Ytrain)

# %%
y7 = grid_rf.predict(xtest)

# %%
accuracy_rF=r2_score(ytest,y6)
accuracy_rF
